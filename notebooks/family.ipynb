# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.graph.utils import extract_genealogical_subgraph
from src.graph import Graph
from src.plot.graph import plot_graph

# %%
g1 = Graph()
g1.add_vertex("A")
g1.add_vertex("B")
g1.add_vertex("E")
g1.add_vertex("C")
g1.add_vertex("D")
g1.add_vertex("E")
g1.add_vertex("F")
g1.add_vertex("G")
g1.add_vertex("H")
g1.add_vertex("I")


g1.add_edge("A", "B")
g1.add_edge("B", "D")
g1.add_edge("B", "F")
g1.add_edge("C", "A")
g1.add_edge("C", "H")
g1.add_edge("G", "A")
g1.add_edge("E", "B")
g1.add_edge("H", "I")

plot_graph(g1)

# %%
g1._graph
# Out:
# defaultdict(list,
#             {'A': ['B'],
#              'B': ['D', 'F'],
#              'E': ['B'],
#              'C': ['A', 'H'],
#              'D': [],
#              'F': [],
#              'G': ['A'],
#              'H': ['I'],
#              'I': []})

# %%
plot_graph(extract_genealogical_subgraph(g1, 'E'))

# %%
g2 = Graph()
g2.add_vertex("A")
g2.add_vertex("B")
g2.add_vertex("C")
g2.add_vertex("D")
g2.add_vertex("E")
g2.add_vertex("F")
g2.add_vertex("G")
g2.add_vertex('H')
g2.add_vertex('I')
g2.add_vertex('J')
g2.add_vertex('A1')
g2.add_vertex('B1')

g2.add_edge("A", "B")
g2.add_edge("B", "C")
g2.add_edge("C", "D")
g2.add_edge("B", "E")
g2.add_edge("G", "E")
g2.add_edge("G", "F")
g2.add_edge("A", "H")
g2.add_edge("H", "I")
g2.add_edge("E", "J")
g2.add_edge("A1", "A")
g2.add_edge("A1", "B1")

# %%
plot_graph(g2)

# %%
plot_graph(extract_genealogical_subgraph(g2, 'F'))
